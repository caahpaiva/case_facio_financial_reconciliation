# %%
import pandas as pd

fundo = pd.read_parquet("posicao_fundo.parquet")
facio = pd.read_parquet("posicao_facio.parquet")

fundo.to_csv("posicao_fundo.csv", index=False)
facio.to_csv("posicao_facio.csv", index=False)
